# %%
import matplotlib.pyplot as plt
import numpy as np
import cv2 as cv
import pandas as singgih
import math
import libraryPCDFahir as lib

# %%
var_image = plt.imread("shenhe.jpg")
plt.imshow(var_image)

# %%
gray=lib.togray(var_image)
plt.imshow(gray,cmap='gray')

# %%
listall=lib.splitimage(gray,2,2)

# %%
for i in range(2):
    # Iterate over columns
    for j in range(2):
        # Display the image at position (i, j) in listall
        plt.subplot(3, 6, i*6 + j + 1)  # Adjust subplot position
        plt.imshow(listall[i][j], cmap='gray')
        plt.axis('off')  # Turn off axis
plt.show()

# %%
for i in range(2):
    for j in range(2):
        listall[i][j]=lib.rotasi(listall[i][j],derajat=135)
        listall[i][j]=lib.translasi(listall[i][j],x=int(listall[i][j].shape[0]/2),y=int(listall[i][j].shape[1]/2))
        listall[i][j]=lib.rotasi(listall[i][j],derajat=135)
        listall[i][j]=lib.translasi(listall[i][j],x=int(listall[i][j].shape[0]/2),y=int(listall[i][j].shape[1]/2))
#estimate 20s
#for 4 estimate 1m 3s up to 22s

# %%
plt.subplot(2, 2, 1)
plt.imshow(listall[0][0], cmap='gray')   
plt.axis('off')  # Turn off axis  
plt.subplot(2, 2, 2)
plt.imshow(listall[0][1], cmap='gray')
plt.axis('off')  # Turn off axis
plt.subplot(2, 2, 3)
plt.imshow(listall[1][0], cmap='gray')
plt.axis('off')  # Turn off axis
plt.subplot(2, 2, 4)
plt.imshow(listall[1][1], cmap='gray')
plt.axis('off')  # Turn off axis
plt.show()

# %%
c=lib.Syncfusion(listall)

# %%
plt.imshow(c,cmap='gray')

# %%
splitedimage=lib.splitimage(c,2,2)

# %%
eq,_=lib.equalisasi(gray)
plt.subplot(1,2,1)
plt.imshow(eq,cmap='gray')
plt.subplot(1,2,2)
plt.imshow(gray,cmap='gray')
plt.show()

# %%
index,yaxis=lib.histvar(gray)
_,yaxisequal=lib.histvar(eq)

# %%
plt.bar(index,yaxis,color="blue")
plt.bar(index,yaxisequal,color="green")
# Out:
# <BarContainer object of 256 artists>

# %%
image2 = plt.imread("kurumi.jpg")

image3 = plt.imread("megumin.jpg")
plt.subplot(1,2,1)
plt.imshow(image2)
plt.subplot(1,2,2)
plt.imshow(image3)
plt.show()

# %%
gray2 = lib.togray(image2)
gray3 = lib.togray(image3)
plt.subplot(1,3,1)
plt.imshow(gray2,cmap='gray')
plt.axis('off')
plt.subplot(1,3,2)
plt.imshow(gray3,cmap='gray')
plt.axis('off')
plt.subplot(1,3,3)
plt.imshow(eq,cmap='gray')
plt.axis('off')
plt.show()

# %%
ha=lib.splitSpec(gray,gray2,gray3,2,2)
plt.imshow(ha,cmap='gray')
